# %%
import json
from tqdm import tqdm

def load_Yelp_data(path):
    final_user_set = {}
    final_item_set = {}
    edge_index = {}
    edge_feature = {}

    with open(path+'yelp_academic_dataset_user.json', 'r', encoding='utf-8') as f:
        all_data = f.readlines()
        for line in tqdm(all_data):
            current_data = json.loads(line)
            current_node = current_data['user_id']
            del current_data['user_id']
            final_user_set[current_node] = current_data      
   
                
    with open(path+'yelp_academic_dataset_business.json', 'r', encoding='utf-8') as f:
        all_data = f.readlines()
        for line in tqdm(all_data):
            current_data = json.loads(line)
            current_node = current_data['business_id']
            del current_data['business_id']
            final_item_set[current_node] = current_data      
            
    
    with open(path+'yelp_academic_dataset_review.json', 'r', encoding='utf-8') as f:
        all_data = f.readlines()
        for line in tqdm(all_data):
            current_data = json.loads(line)
            current_business = current_data['business_id']
            current_user = current_data['user_id']
            cool_level = int(current_data['funny']) + int(current_data['useful']) + int(current_data['cool'])
            current_edge_feature = {'date':current_data['date'], 'text':current_data['text'], 'rate':current_data['stars'], 'rate_level':cool_level}
            edge_feature[str(current_user) + '|' + str(current_business)] = current_edge_feature
            if current_user in edge_index:
                edge_index[current_user].append(current_business)
            else:
                edge_index[current_user] = [current_business]
                
    return edge_index, final_user_set, final_item_set, edge_feature

# %%
edge_index, final_user_feature_dic, final_item_feature_dic, edge_feature = load_Yelp_data('yelp_dataset/')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 2189457/2189457 [00:28<00:00, 77921.36it/s]
# 100%|███████████████████████████████████████████████████████████████████████| 160585/160585 [00:03<00:00, 50583.18it/s]
# 100%|█████████████████████████████████████████████████████████████████████| 8635403/8635403 [05:19<00:00, 27055.85it/s]

# %%
import ast
def attribute_analysis(attr):
    final_str = ''
    for key in attr.keys():
        if attr[key][0] != '{' and attr[key][-1] != '}':
            final_str += '{} is {}. '.format(key, attr[key])
        else:
            values = json.loads(json.dumps(ast.literal_eval(attr[key])))
            final_str += 'The business contains {} where '.format(key)
            for sub_key in values:
                final_str+='{} is {}. '.format(sub_key, values[sub_key])
    return final_str

def feature_transformation(final_feature):
    final_feature_dic = {}
    for key_name in tqdm(list(final_feature.keys())):
        feature = final_feature[key_name]
        if 'fans' in feature.keys(): # User feature
            if len(feature['elite'])!=0:
                elite_period = max([int(i) for i in feature['elite'].split(',')]) - min([int(i) for i in feature['elite'].split(',')])
            else:
                elite_period = 0
            friends_count = len(feature['friends'].split(', '))
            valid_user_feature = [feature[i] for i in list(feature.keys())[-13:]]
            temp_feature = [feature['review_count'], feature['useful'], feature['funny'], feature['cool'],elite_period, friends_count]
            final_feature_val = temp_feature + valid_user_feature
            final_feature_dic[key_name] = final_feature_val
        else:
            name = feature['name']
            address = feature['address']
            city = feature['city']
            state = feature['state']
            postal_code = feature['postal_code']
            stars = feature['stars']
            review_count = feature['review_count']
            attribures = feature['attributes']
            categories = 'The business offers {}. '.format(feature['categories'])
            current_address_information = 'The business {} located at {},{},{},{}. '.format(name, address,city,state, postal_code)
            if attribures is not None:
                attributes_information = attribute_analysis(attribures)
            else:
                attributes_information = ''
            final_information = categories + current_address_information + attributes_information
            final_feature_dic[key_name] = final_information
    return final_feature_dic

# %%
final_item_feature = feature_transformation(final_item_feature_dic)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 160585/160585 [00:08<00:00, 19261.71it/s]

# %%
import torch
import math
import torch.nn as nn
import numpy as np
import torch.nn.functional as F
from torch.nn import Linear, Conv1d
from torch_geometric.nn import GCNConv, RGCNConv, global_sort_pool, global_add_pool
from torch_geometric.utils import dropout_adj
def scaled_dot_product(q, k, v, mask=None):
    d_k = q.size()[-1]
    attn_logits = torch.matmul(q, k.transpose(-2, -1))
    attn_logits = attn_logits / math.sqrt(d_k)
    if mask is not None:
        attn_logits = attn_logits.masked_fill(attn_logits == 0, -9e15)
    attention = F.softmax(attn_logits, dim=-1)
    values = torch.matmul(attention, v)
    return values, attention


class MultiheadAttention(nn.Module):

    def __init__(self, input_dim, embed_dim, num_heads):
        super().__init__()
        assert embed_dim % num_heads == 0, "Embedding dimension must be 0 modulo number of heads."

        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.head_dim = embed_dim // num_heads

        # Stack all weight matrices 1...h together for efficiency
        # Note that in many implementations you see "bias=False" which is optional
        self.qkv_proj = nn.Linear(input_dim, 3*embed_dim)
        self.o_proj = nn.Linear(embed_dim, embed_dim)

        self._reset_parameters()

    def _reset_parameters(self):
        # Original Transformer initialization, see PyTorch documentation
        nn.init.xavier_uniform_(self.qkv_proj.weight)
        self.qkv_proj.bias.data.fill_(0)
        nn.init.xavier_uniform_(self.o_proj.weight)
        self.o_proj.bias.data.fill_(0)

    def forward(self, x, mask=None, return_attention=False):
        batch_size, seq_length, embed_dim = x.size()
        qkv = self.qkv_proj(x)

        # Separate Q, K, V from linear output
        qkv = qkv.reshape(batch_size, seq_length, self.num_heads, 3*self.head_dim)
        qkv = qkv.permute(0, 2, 1, 3) # [Batch, Head, SeqLen, Dims]
        q, k, v = qkv.chunk(3, dim=-1)

        # Determine value outputs
        values, attention = scaled_dot_product(q, k, v, mask=mask)
        values = values.permute(0, 2, 1, 3) # [Batch, SeqLen, Head, Dims]
        values = values.reshape(batch_size, seq_length, embed_dim)
        o = self.o_proj(values)

        if return_attention:
            return o, attention
        else:
            return o
class EncoderBlock(nn.Module):

    def __init__(self, input_dim, num_heads, dim_feedforward, dropout=0.3):
        """
        Inputs:
            input_dim - Dimensionality of the input
            num_heads - Number of heads to use in the attention block
            dim_feedforward - Dimensionality of the hidden layer in the MLP
            dropout - Dropout probability to use in the dropout layers
        """
        super().__init__()

        # Attention layer
        self.self_attn = MultiheadAttention(input_dim, input_dim, num_heads)

        # Two-layer MLP
        self.linear_net = nn.Sequential(
            nn.Linear(input_dim, dim_feedforward),
            nn.Dropout(dropout),
            nn.ReLU(inplace=True),
            nn.Linear(dim_feedforward, input_dim)
        )

        # Layers to apply in between the main layers
        self.norm1 = nn.LayerNorm(input_dim)
        self.norm2 = nn.LayerNorm(input_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, mask=None):
        # Attention part
        attn_out = self.self_attn(x, mask=mask)
        x = x + self.dropout(attn_out)
        x = self.norm1(x)

        # MLP part
        linear_out = self.linear_net(x)
        x = x + self.dropout(linear_out)
        x = self.norm2(x)

        return x

class PositionalEncoding(nn.Module):

    def __init__(self, d_model, max_len=5000):
        """
        Inputs
            d_model - Hidden dimensionality of the input.
            max_len - Maximum length of a sequence to expect.
        """
        super().__init__()

        # Create matrix of [SeqLen, HiddenDim] representing the positional encoding for max_len inputs
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)

        # register_buffer => Tensor which is not a parameter, but should be part of the modules state.
        # Used for tensors that need to be on the same device as the module.
        # persistent=False tells PyTorch to not add the buffer to the state dict (e.g. when we save the model)
        self.register_buffer('pe', pe, persistent=False)

    def forward(self, x):
        x = x + self.pe[:, :x.size(1)]
        return x
    
class IGMC(torch.nn.Module):
    # The GNN model of Inductive Graph-based Matrix Completion. 
    # Use RGCN convolution + center-nodes readout.
    def __init__(self, device, gconv=RGCNConv, latent_dim=[32, 32, 32, 32], 
                 num_relations=5, num_bases=2, regression=False, adj_dropout=0.2, 
                 force_undirected=False, n_side_features=0, 
                 multiply_by=1, model_type = 'lstm', num_layers = None, num_heads = 8):
        super(IGMC, self).__init__()
        self.regression = regression
        self.adj_dropout = adj_dropout 
        self.force_undirected = force_undirected
        self.model_type = model_type
        self.n_side_features = n_side_features
        self.device = device
        if model_type == 'lstm':
            self.time_module = LSTM_variable_input(embedding_dim=n_side_features, hidden_dim=n_side_features)
            
        elif model_type == 'attention' and num_layers is not None:
            input_dim = n_side_features
            self.num_layers = num_layers
            dim_feedforward = n_side_features

            self.time_module = torch.nn.ModuleList([EncoderBlock(input_dim=input_dim, dim_feedforward=dim_feedforward, num_heads = num_heads) for _ in range(num_layers)])
            
        
        self.multiply_by = multiply_by
        self.convs = torch.nn.ModuleList()
        self.convs.append(gconv(4, latent_dim[0], num_relations, num_bases))
        for i in range(0, len(latent_dim)-1):
            self.convs.append(gconv(latent_dim[i], latent_dim[i+1], num_relations, num_bases)) 
        
        self.lin1 = Linear(2*sum(latent_dim)+n_side_features*2+19, n_side_features)
        self.lin1_2 = Linear(n_side_features, 128)
        
        if self.regression:
            self.lin2 = Linear(128, 1)
        else:
            self.lin2 = Linear(128, 5)
            
    def reset_parameters(self):
        for conv in self.convs:
            conv.reset_parameters()
        self.lin1.reset_parameters()
        self.lin2.reset_parameters()
        
    def forward(self, data):
        x, edge_index, edge_type, batch, timestamp= data.x, data.edge_index, data.edge_type, data.batch, data.time_val
        if self.adj_dropout > 0:
            edge_index, edge_type = dropout_adj(
                edge_index, edge_type, p=self.adj_dropout, 
                force_undirected=self.force_undirected, num_nodes=len(x), 
                training=self.training
            )
        
        concat_states = []
        for conv in self.convs:
            x = torch.tanh(conv(x, edge_index, edge_type))
            concat_states.append(x)
    
        concat_states = torch.cat(concat_states, 1)
        users = data.x[:, 0] == 1
        items = data.x[:, 1] == 1
        
        user_index = users.nonzero(as_tuple=True)[0]

        final_feature = data.side_feature
        Item_list_all = []
        len_all = []
        for user in user_index:
            current_item_idx= (edge_index[0] == user).nonzero(as_tuple=True)[0]
            current_item = torch.index_select(edge_index[1],0, current_item_idx)
            if current_item_idx.shape[0] == 0:
                print('exception occur')
                current_item_idx = (edge_index[1] == user).nonzero(as_tuple=True)[0]
                current_item = torch.index_select(edge_index[0],0, current_item_idx)
            current_time = torch.index_select(timestamp, 0, current_item_idx)
            _, time_indices = torch.sort(current_time)
            temp_dic = dict(zip(time_indices.tolist(),current_item.tolist()))
            sort_dic = dict(sorted(temp_dic.items()))
            current_items = torch.index_select(final_feature, 0, torch.tensor(list(sort_dic.values())).to(self.device))
            Item_list_all.append(current_items)
            len_all.append(current_item.shape[0])
        

    
        final_time_feature = torch.nn.utils.rnn.pad_sequence(Item_list_all, batch_first=True)
        
        if self.model_type == 'attention':
            max_len = max(len_all)
            pos_encode =  PositionalEncoding(self.n_side_features, max_len=max_len).to(self.device)
            final_time_feature = pos_encode(final_time_feature)

        
        
        if self.model_type == 'attention':
            for l in self.time_module:
                len_all = torch.tensor(len_all)
                mask = torch.arange(final_time_feature.size(1))[None, :] < len_all[:, None]
                mask = mask.to(device)
                final_time_feature = l(final_time_feature, mask=mask)
            # Mean pooling for the transformers's output
            input_mask_expanded = mask.unsqueeze(-1).expand(final_time_feature.size()).float()
            sum_embeddings = torch.sum(final_time_feature * input_mask_expanded, 1)
            sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
            time_feature = sum_embeddings / sum_mask
        else:
            time_feature = self.time_module(final_time_feature,len_all)
            

        
        user_feature = torch.cat([concat_states[users], final_feature[users][:,:19], time_feature], 1)
        item_feature = torch.cat([concat_states[items], final_feature[items]], 1)
        
        x = torch.cat([user_feature, item_feature], 1)
#         x = torch.cat([concat_states[users], concat_states[items]], 1)        
#         x = torch.cat([x, final_feature[users][:,:19], final_feature[items], time_feature], 1)
        
        x = F.relu(self.lin1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(self.lin1_2(x))
        x = F.dropout(x, p=0.4, training=self.training)
        x = self.lin2(x)
        if self.regression:
            return x[:, 0] * self.multiply_by, user_feature, item_feature
        else:
            return F.log_softmax(x, dim=-1), user_feature, item_feature

# %%
if torch.cuda.is_available():
    device = torch.device('cuda:0')
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
else:
    device = torch.device('cpu')

# %%
model = IGMC(
    device= device,
    latent_dim=[32, 32, 32, 32], 
    num_relations=5, 
    num_bases=4, 
    regression=False, 
    adj_dropout=0.3, 
    force_undirected=False, 
    n_side_features=768, 
    multiply_by=1,
    model_type = 'attention',
    num_layers = 1,
)

# %%
import torch
import os
def load_model(res_dir,epoch,model):
    model_name = os.path.join(res_dir, 'model_checkpoint{}.pth'.format(epoch))
    model.load_state_dict(torch.load(model_name))
    return model

# %%
PGN_model = load_model('Data', '60', model)

# %%
import json
new_item_feature =  json.load( open( "Data/new_item_feature.json" ) )
user_embedding =  json.load( open( "Data/user_embedding.json" ) )
item_embedding =  json.load( open( "Data/item_embedding.json" ) )
user_embedding = {k: user_embedding[k][0][0] for k in user_embedding.keys()}

# %%
import faiss
import json
import torch
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModel

u_dict = json.load( open( "Data/u_dict.json" ) )
v_dict = json.load( open( "Data/v_dict.json" ) )
model_name = "sentence-transformers/distilbert-base-nli-mean-tokens"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model_encoder = AutoModel.from_pretrained(model_name).to(device) 

class Generate_dataset(Dataset):
    def __init__(self, data,tokenizer,device, type):
        self.data = data
        self.device = device
        self.tokenizer = tokenizer
        self.type = type
    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        if self.type == 'list':
            content = self.data[idx]
        elif self.type == 'dataframe':
            content = self.data.iloc[idx][0]
        content_encoded_input = self.tokenizer(content, padding='max_length', truncation=True,
                                               max_length=256)
        input_ids = torch.tensor(content_encoded_input['input_ids']).to(self.device)
        attention_mask = torch.tensor(content_encoded_input['attention_mask']).to(self.device)
        sample = {'input_ids': input_ids, 'attention_mask': attention_mask}
        return sample


class Sentence_encoding():
    
    def __init__(self, model, tokenizer,device):
        self.model = model
        self.tokenizer = tokenizer
        self.device = device 
    #Mean Pooling - Take attention mask into account for correct averaging
    def mean_pooling(self,model_output, attention_mask):
        token_embeddings = model_output[0] #First element of model_output contains all token embeddings
        input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
        sum_embeddings = torch.sum(token_embeddings * input_mask_expanded, 1)
        sum_mask = torch.clamp(input_mask_expanded.sum(1), min=1e-9)
        return sum_embeddings / sum_mask

    def encode(self, final_content, batch_size, type):
        dataset = Generate_dataset(final_content, self.tokenizer, self.device, type)
        dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)
        if type == 'list':
            outputs = []
            self.model.eval()
            with torch.no_grad():
                for data in tqdm(dataloader):
                    model_output = self.model(input_ids=data['input_ids'], attention_mask=data['attention_mask'])
                    sentence_embeddings = self.mean_pooling(model_output, data['attention_mask'])
                    outputs.append(sentence_embeddings)
            return torch.cat(outputs, dim=0)
        elif type == 'dataframe':
            outputs = {}
            temp_index = 0
            for data in tqdm(dataloader):
                with torch.no_grad():
                    model_output = self.model(input_ids=data['input_ids'], attention_mask=data['attention_mask'])
                    sentence_embeddings = self.mean_pooling(model_output, data['attention_mask'])
                    for index, i in enumerate(sentence_embeddings):
                        final_index = temp_index + index
                        outputs[final_content['News_ID'][final_index]] = sentence_embeddings[index].tolist()
                    temp_index+=batch_size
            return outputs


def request_encoder(request,model,tokenizer, device):
    model.eval()
    encoder = Sentence_encoding(model, tokenizer,device)
    final_items_embedding = encoder.encode([request],1,'list')
    return final_items_embedding[0].tolist()

def Faiss_search(new_item_feature,request_embedding, TopN):
    embeddings = np.array([embedding for embedding in list(new_item_feature.values())]).astype("float32")
    # Step 2: Instantiate the index
    index = faiss.IndexFlatL2(embeddings.shape[1])

    # Step 3: Pass the index to IndexIDMap
    index = faiss.IndexIDMap(index)

    # Step 4: Add vectors and their IDs
    ids_dic = {index:val for index, val in enumerate(new_item_feature.keys())} 
    
    
    IDs = np.array(list(ids_dic.keys()))
    IDs = np.asarray(IDs.astype('int64'))
    index.add_with_ids(embeddings, IDs)

    # Retrieve the 10 nearest neighbours
    D, I = index.search(np.array([request_embedding]).astype("float32"), k=TopN)
    searched_ID = [ids_dic[i] for i in I[0]][::-1]
    return searched_ID

# %%
class Rate_model(torch.nn.Module):
    def __init__(self, pretrained_model):
        super(Rate_model, self).__init__()
        self.lin1 = pretrained_model.lin1
        self.lin2 = pretrained_model.lin1_2
        self.lin3 = pretrained_model.lin2
    def forward(self, item_feature, user_feature):
        x = torch.cat([user_feature, item_feature], 1)
        x = F.relu(self.lin1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(self.lin2(x))
        x = F.dropout(x, p=0.4, training=self.training)
        x = self.lin3(x)
        return F.log_softmax(x, dim=-1).sigmoid()
# Could implement multi_item comparision

# %%
request = 'I like Thai food'

TopN_food = 20

# %%
request_embedding = request_encoder(request,model_encoder,tokenizer, device)
searched_ID= Faiss_search(new_item_feature,request_embedding,TopN_food)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 35.35it/s]

# %%
# for i in searched_ID:
#     print(final_item_feature[i])

# %%
Item_ID = [v_dict[i] for i in searched_ID]

# %%
final_valid_items = []
for i in Item_ID:
    if str(i) in item_embedding.keys():
        final_valid_items.append(str(i))

# %%
final_valid_items_embeddings = [item_embedding[i] for i in final_valid_items]

# %%
def evalutate_candidate_user(model, valid_item_embeddings, user_embedding, TopN_user):
    all_recommend = []
    model.eval()
    with torch.no_grad():
        for item in tqdm(valid_item_embeddings):
            user_rank = {}
            item = item[0][0] + [0 for _ in range(19)]
            candidate_user_embedding_ID = Faiss_search(user_embedding,item,TopN_user)
            for user in candidate_user_embedding_ID:
                user_emb, item_emb = torch.tensor(user_embedding[user]).to(device), torch.tensor(item).to(device)
                user_emb = user_emb.unsqueeze(dim=0)
                item_emb = item_emb[:-19].unsqueeze(dim=0)
                rank_score = model(item_emb, user_emb)
                user_rank[user] = [rank_score.tolist()[0][-1]]
            all_recommend.append(user_rank)
    return all_recommend
# Add batch for speed up
rate_model = Rate_model(PGN_model).to(device)

# %%
all_recommend = evalutate_candidate_user(rate_model, final_valid_items_embeddings, user_embedding,1000)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 20/20 [00:19<00:00,  1.01it/s]

# %%
import operator
N = 100
u_dict_revserd = {v: k for k, v in u_dict.items()}
all_users_recommend = []
for user_rank in all_recommend:
    sorted_user_rank = sorted(user_rank.items(), key=lambda x: x[1], reverse=True)
    Top_N_user = sorted_user_rank[:N]
    TopN_user = [u_dict_revserd[int(i)] for i in [item[0] for item in Top_N_user]]
    all_users_recommend.append(TopN_user)

TopN_user_common =  list(set.intersection(*map(set, all_users_recommend)))
TopN_user_all = [j for i in all_users_recommend for j in i]
Final_TopN_user = list(set(TopN_user_all) - set(TopN_user_common))

# %%
keywords = ['Thai']

# %%
# I want to eat pasta
count = 0
print(len(Final_TopN_user))
for i in Final_TopN_user:
    print('User name:',final_user_feature_dic[i]['name'])
    users_items = edge_index[i]
    
    print('---------------------------------')
    print('The resturant that the user visited:')
    for item in users_items:
        cat = final_item_feature_dic[item]['categories']
        print(cat)
        m =0
        for keyword in keywords:
            if keyword in cat:
                count +=1
                m = 1
                break
        if m == 1:
            break
        
    print('\n')
# Out:
# 70
# User name: Gene
# ---------------------------------
# The resturant that the user visited:
# American (New), American (Traditional), Restaurants, Burgers
# Restaurants, Event Planning & Services, Modern European, Pizza, Personal Chefs, Italian, American (New)
# Sandwiches, Barbeque, Southern, Restaurants, Salad
# Tapas/Small Plates, Restaurants, Breakfast & Brunch, American (New)
# Restaurants, Izakaya, Nightlife, Barbeque, Ramen, Cocktail Bars, Food, Japanese, Smokehouse, Bars
# Event Planning & Services, Hotels & Travel, Hotels
# Dive Bars, Bars, Burgers, Restaurants, Nightlife, Cocktail Bars, American (Traditional)
# Pizza, Restaurants, Food Trucks, Food
# Local Flavor, Salad, Sandwiches, Restaurants, Barbeque, Food, Food Stands
# Nightlife, Bars
# Restaurants, Food Trucks, Barbeque, Sandwiches, Food
# Restaurants, Pizza, American (Traditional), Nightlife, Bars, Breakfast & Brunch, Beer Bar
# American (New), Breakfast & Brunch, Pubs, American (Traditional), Wine Bars, Bars, Nightlife, Beer Gardens, Restaurants
# Patisserie/Cake Shop, Coffee & Tea, Wine Bars, Cafes, French, Food, Bars, Nightlife, Restaurants
# Pizza, Food, Beer, Wine & Spirits, Nightlife, Restaurants, Bars, Italian, Breakfast & Brunch, Cocktail Bars
#
#
# User name: Colin
# ---------------------------------
# The resturant that the user visited:
# Sporting Goods, Shopping, Bikes
# Noodles, Restaurants, Chinese, Vietnamese
# Home & Garden, Kitchen & Bath, Hardware Stores, Shopping
# Restaurants, Asian Fusion, Food, Korean, Burgers
# Food, Food Trucks, Burgers, Restaurants
# Pizza, Italian, Restaurants
# Chinese, Restaurants
# Food, Breweries
# Food, Coffee & Tea
# Restaurants, Vietnamese
# Canadian (New), Mexican, Restaurants
#
#
# User name: Natalie
# ---------------------------------
# The resturant that the user visited:
# Restaurants, Breakfast & Brunch, French, Creperies, Salad
# Health & Medical, Retirement Homes
# Food, Health Markets, Cafes, Specialty Food, Restaurants, Grocery
# Food, Health Markets, Cafes, Specialty Food, Restaurants, Grocery
# Auto Repair, Gas Stations, Automotive, Smog Check Stations, Trailer Repair, Oil Change Stations, Tires
# Mass Media, Print Media
# Arts & Entertainment, Social Clubs
# Lebanese, Restaurants, Middle Eastern
# Health & Medical, Neurologist, Doctors
# Specialty Schools, Cooking Schools, Shopping, Education
#
#
# User name: Martin
# ---------------------------------
# The resturant that the user visited:
# Restaurants, Steakhouses, American (New), American (Traditional)
# Restaurants, Burgers, Sandwiches, Pizza, Cafes, Wine Bars, Breakfast & Brunch, Nightlife, Pubs, Bars
# Restaurants, Noodles, Vietnamese
# Halal, Mediterranean, Restaurants, Food, Food Trucks
# Restaurants, Tacos, Mexican, Vegetarian, Breakfast & Brunch, Tex-Mex
# Pakistani, Kosher, Vegan, Vegetarian, Restaurants, Indian, Buffets
# Vietnamese, Mexican, Cafes, Restaurants, Asian Fusion, Sandwiches, Salad
# Food, Ethnic Food, Specialty Food, Mediterranean, Restaurants
# Bars, Beer, Wine & Spirits, Breakfast & Brunch, Restaurants, Seafood, American (New), Diners, Food, Nightlife
# Active Life, Team Building Activities, Escape Games, Event Planning & Services, Dinner Theater, Restaurants
# American (New), Restaurants
#
#
# User name: Brian
# ---------------------------------
# The resturant that the user visited:
# Food, Grocery
# Smog Check Stations, Car Dealers, Automotive, Gas Stations, Body Shops, Tires, Auto Repair
# Restaurants, Italian, Event Planning & Services, Sandwiches, Specialty Food, Food, International Grocery, Caterers, Delis
# Home Services, Plumbing
# Grocery, Seafood Markets, Specialty Food, Restaurants, Ethnic Grocery, Food, Food Court, International Grocery, Korean, Pan Asian
# Restaurants, Italian, Seafood, Food, Coffee & Tea
# Breakfast & Brunch, Restaurants, Mexican, Tacos
# Restaurants, Seafood, Noodles, Chinese
# Home Services, Electricians, Heating & Air Conditioning/HVAC
# Seafood, Food, Caterers, Pizza, Sandwiches, Restaurants, Event Planning & Services, Food Delivery Services
# Cafes, Breakfast & Brunch, Grocery, Fruits & Veggies, Butcher, Restaurants, Specialty Food, Food
# Restaurants, Japanese, Food, Sushi Bars
# Furniture Stores, Appliances, Home & Garden, Shopping, Electronics, Home Services, Home Theatre Installation, High Fidelity Audio Equipment
# Restaurants, Mexican, Food
# Restaurants, Salad, Grocery, Food
# Transportation, Hotels & Travel, Taxis
# Breakfast & Brunch, Restaurants
# Restaurants, International Grocery, Ethnic Food, Specialty Food, Shopping, Asian Fusion, Grocery, Flowers & Gifts, Food, Filipino
# Mediterranean, Italian, Modern European, Restaurants
# Mediterranean, Italian, Modern European, Restaurants
# Sushi Bars, Japanese, Restaurants
# Shopping, Fabric Stores, Arts & Crafts
# Pizza, Restaurants
# Nightlife, Cocktail Bars, Restaurants, Bars, Seafood, Italian
#
#
# User name: Tiffany
# ---------------------------------
# The resturant that the user visited:
# Hotels & Travel, Hotels, Event Planning & Services, Venues & Event Spaces
# Event Planning & Services, Flowers & Gifts, Shopping, Florists, Floral Designers, Wedding Planning
# Gluten-Free, Vegan, Restaurants, Vegetarian
# Skin Care, Beauty & Spas, Nail Salons, Nail Technicians, Hair Salons
# DJs, Event Planning & Services
# Computers, Shopping, Mobile Phones, Electronics
# Restaurants, Food, American (Traditional), Ice Cream & Frozen Yogurt, Burgers
# Skin Care, Beauty & Spas, Makeup Artists, Hair Removal
# Formal Wear, Local Services, Sewing & Alterations, Shopping, Fashion
# Ice Cream & Frozen Yogurt, Bakeries, Food, Desserts
# Orthodontists, Health & Medical, Periodontists, Cosmetic Dentists, Endodontists, Dentists, General Dentistry
# Venues & Event Spaces, Party Supplies, Flowers & Gifts, Event Planning & Services, Shopping, Florists
# Golf, Country Clubs, Wedding Planning, Venues & Event Spaces, Arts & Entertainment, Event Planning & Services, Caterers, Active Life
#
#
# User name: Mary
# ---------------------------------
# The resturant that the user visited:
# Seafood, Seafood Markets, Specialty Food, Cocktail Bars, Restaurants, Food, Bars, Nightlife
# Restaurants, Mexican, Cocktail Bars, Bars, Tacos, Nightlife
# Car Rental, Hotels & Travel
# Food, Delis, Restaurants, Bakeries
# Italian, Pizza, Ethnic Grocery, Food, Restaurants
# Restaurants, Sandwiches, Mediterranean, Pizza, Food
# Breakfast & Brunch, American (Traditional), Restaurants
# Seafood, Tapas/Small Plates, Sandwiches, Restaurants
# Mexican, Restaurants
# Restaurants, Pizza
# Bikes, Bike Repair/Maintenance, Local Services, Bike Rentals, Active Life, Sporting Goods, Shopping
# Hair Removal, Nail Salons, Day Spas, Eyelash Service, Skin Care, Waxing, Beauty & Spas
# Restaurants, Mexican
# Lounges, Bars, Chinese, Sushi Bars, Restaurants, Nightlife, Asian Fusion, Japanese
# Restaurants, Sushi Bars, Chinese, Japanese
# Mexican, Street Vendors, Food Trucks, Restaurants, Fast Food, Food, Event Planning & Services, Tex-Mex, Food Delivery Services, Caterers, Tacos
#
#
# User name: Grace
# ---------------------------------
# The resturant that the user visited:
# Hair Salons, Blow Dry/Out Services, Waxing, Hair Removal, Beauty & Spas, Hair Extensions
# Parking, Automotive
# Food, Food Delivery Services, Beer, Wine & Spirits, Grocery
# Recreation Centers, Caterers, Breakfast & Brunch, Nightlife, Buffets, Active Life, Mexican, Restaurants, American (Traditional), Sports Bars, Bars, Event Planning & Services
# Hair Salons, Nail Salons, Day Spas, Beauty & Spas
# Steakhouses, Restaurants, Seafood
# Trainers, Dentists, Endodontists, Active Life, Health & Medical, Cosmetic Dentists, General Dentistry, Fitness & Instruction
# Waxing, Eyelash Service, Eyebrow Services, Hair Removal, Beauty & Spas, Cosmetics & Beauty Supply, Shopping
# Bars, Cafes, Nightlife, French, Restaurants
# Nail Salons, Beauty & Spas
# Bakeries, Custom Cakes, Desserts, Food, Cupcakes
# Real Estate, Home Services, Apartments
# Restaurants, Thai
#
#
# User name: Martha
# ---------------------------------
# The resturant that the user visited:
# Restaurants, Breakfast & Brunch, Italian
# Restaurants, Breakfast & Brunch, Italian
# Mexican, Lounges, Nightlife, American (New), Restaurants, Bars, Cocktail Bars
# Mexican, Restaurants
# Restaurants, Tex-Mex, Nightlife, Cocktail Bars, Tapas Bars, Mexican, Breakfast & Brunch, Latin American, Bars, American (New), Tapas/Small Plates
# Food, Grocery, Pasta Shops, Desserts, Salad, Specialty Food, Pizza, Restaurants, Italian
# Nightlife, Restaurants, Bars, Italian
# Food, Grocery, Pasta Shops, Desserts, Salad, Specialty Food, Pizza, Restaurants, Italian
# Coffee & Tea, Restaurants, Food, Bakeries, Cafes, Internet Cafes
# Tapas Bars, Gastropubs, Spanish, Restaurants
# Food, Coffee & Tea, Desserts, Bakeries
# Sushi Bars, Restaurants, Nightlife, Bars
# Tex-Mex, Bars, Mexican, Latin American, Restaurants, Nightlife, Vegan
# Food, Coffee & Tea, Desserts, Bakeries
# Specialty Food, American (New), Bars, Food, Nightlife, American (Traditional), Restaurants, Breakfast & Brunch
#
#
# User name: Kristen
# ---------------------------------
# The resturant that the user visited:
# Laundry Services, Local Services, Dry Cleaning & Laundry
# Shopping, Pet Groomers, Pets, Home & Garden, Hardware Stores, Pet Stores, Pet Sitting, Pet Services, Pet Boarding
# Korean, Japanese, Asian Fusion, Restaurants
# Steakhouses, Japanese, Restaurants, Soup
# Restaurants, Italian, Pizza, Food, Desserts
# Nail Salons, Beauty & Spas
# American (Traditional), Bars, Pubs, Restaurants, Chicken Wings, Nightlife
# Accessories, Fashion, Shoe Stores, Shopping
# Pet Sitting, Pet Services, Dog Walkers, Pet Groomers, Pets
# Massage, Hair Stylists, Hair Removal, Hair Salons, Skin Care, Beauty & Spas, Nail Salons
# Bakeries, Food, Restaurants, Breakfast & Brunch, Cafes
# American (Traditional), Italian, Restaurants
# Restaurants, Pubs, American (Traditional), Nightlife, Food, Beer, Wine & Spirits, Bars
# Home Services, Tree Services, Firewood
# Restaurants, American (Traditional)
#
#
# User name: April
# ---------------------------------
# The resturant that the user visited:
# Active Life, Parks
# Salad, Creperies, Breakfast & Brunch, Restaurants
# Caterers, Food, Italian, Pizza, Restaurants, Event Planning & Services
# Seafood, American (New), Bars, Tiki Bars, Restaurants, American (Traditional), Nightlife
# Salad, Restaurants, Bars, Tex-Mex, Mexican, Nightlife
# Bakeries, Cupcakes, Custom Cakes, Food
# Nightlife, Beer Bar, Bars, Restaurants, Gastropubs, American (Traditional)
# Italian, Seafood, Cocktail Bars, Nightlife, Restaurants, Bars, Pizza
# Bakeries, Desserts, Restaurants, Food, Wraps, Burgers, Donuts
# Sushi Bars, Seafood, Japanese, Buffets, Restaurants
# Bike Repair/Maintenance, Local Services, Active Life, Bike Rentals, Shopping, Sporting Goods, Bikes
# Delis, American (New), Event Planning & Services, Caterers, Restaurants, Food, Barbeque, Smokehouse, Desserts
# Italian, Restaurants, Gluten-Free, Pizza
# Chicken Wings, Nightlife, Restaurants, Burgers, American (New), Sports Bars, Bars, Sandwiches
# Desserts, Food, Restaurants, Beer, Wine & Spirits, Mexican, Street Vendors, Tacos
# Food, Desserts, Salad, Restaurants, Sandwiches, Cajun/Creole
# Greek, Mediterranean, Restaurants
# Ice Cream & Frozen Yogurt, Desserts, Shaved Ice, Food
# Restaurants, Delis, Italian, Pizza
# Gyms, Fitness & Instruction, Active Life, Trainers
# Desserts, Bakeries, Patisserie/Cake Shop, Food
#
#
# User name: Hannah
# ---------------------------------
# The resturant that the user visited:
# Food, Coffee & Tea
# Beer, Wine & Spirits, Coffee & Tea, Food, Restaurants, Cafes
# Shopping, Hair Salons, Beauty & Spas, Cosmetics & Beauty Supply
# Local Services, Child Care & Day Care, Gyms, Weight Loss Centers, Yoga, Health & Medical, Pilates, Active Life, Fitness & Instruction
# Food, Restaurants, Pakistani, Caterers, Vegan, Event Planning & Services, Food Trucks, Asian Fusion
# Food, Coffee & Tea
# Restaurants, Barbeque, Event Planning & Services, Caterers
# Restaurants, American (New), Nightlife, Seafood, Vegetarian, Bars, Wine Bars
# Art Galleries, Professional Services, Beauty & Spas, Shopping, Arts & Entertainment, Tattoo
# Sports Wear, Bike Rentals, Shopping, Fashion, Active Life, Bikes, Sporting Goods
#
#
# User name: Nikki
# ---------------------------------
# The resturant that the user visited:
# Hair Removal, Waxing, Nail Salons, Eyelash Service, Beauty & Spas
# Afghan, Breakfast & Brunch, Burgers, Bars, Restaurants, American (New), Cocktail Bars, Nightlife
# Cryotherapy, Skin Care, Health & Medical, Medical Spas, Beauty & Spas, Massage, Massage Therapy, Acupuncture
# Restaurants, Steakhouses
# Health & Medical, Endocrinologists, Surgeons, Doctors
# Wedding Planning, Party & Event Planning, Event Planning & Services
# Pet Services, Pet Groomers, Pets
# Restaurants, Mexican, Tex-Mex
# Barbeque, Restaurants
# Veterinarians, Pet Services, Pets
# Sewing & Alterations, Local Services, Furniture Reupholstery, Beauty & Spas
#
#
# User name: Christine
# ---------------------------------
# The resturant that the user visited:
# Breakfast & Brunch, Sandwiches, Restaurants, Food, American (Traditional), Coffee & Tea
# Tapas/Small Plates, Restaurants, Breakfast & Brunch, American (New)
# American (New), Food, Beer, Wine & Spirits, Tex-Mex, Restaurants, American (Traditional)
# Event Planning & Services, Lounges, Venues & Event Spaces, Arcades, Active Life, Karaoke, Restaurants, Bowling, Arts & Entertainment, Bars, Nightlife, American (Traditional)
# Nightlife, Bars, Dive Bars, Lounges, Cocktail Bars, Wine Bars
# Makeup Artists, Skin Care, Beauty & Spas, Hair Salons
# Makeup Artists, Skin Care, Beauty & Spas, Hair Salons
# Trainers, Fitness & Instruction, Gyms, Active Life
# Asian Fusion, Chinese, Restaurants
# Skin Care, Eyelash Service, Hair Removal, Beauty & Spas
# Restaurants, Vietnamese
# Active Life, Trainers, Boot Camps, Cycling Classes, Gyms, Fitness & Instruction, Yoga
# Pets, Pet Groomers, Pet Services
# Food, Restaurants, Ice Cream & Frozen Yogurt, Burgers, American (Traditional)
# Bars, Dive Bars, Nightlife, Whiskey Bars, Pubs, Lounges
# Asian Fusion, Sushi Bars, Restaurants, Japanese
# Lounges, Bars, Nightlife
# Thai, Restaurants
#
#
# User name: Michela
# ---------------------------------
# The resturant that the user visited:
# Education, Colleges & Universities
# Argentine, Restaurants, Latin American, Gluten-Free
# Restaurants, Salad, Sandwiches, Coffee & Tea, Food
# Indian, Restaurants, Tapas/Small Plates
# Coffee & Tea, Restaurants, Breweries, American (New), Cafes, Food
# Seafood Markets, Specialty Food, Restaurants, Food, American (New), Seafood
# Restaurants, Food, Cafes, Desserts
# Sandwiches, Vietnamese, Restaurants
# Korean, Street Vendors, Specialty Food, Ethnic Food, Food, Restaurants, Mexican
# Bakeries, Food, Donuts
#
#
# User name: David
# ---------------------------------
# The resturant that the user visited:
# Restaurants, Pizza
# Sunglasses, Health & Medical, Shopping, Optometrists, Eyewear & Opticians
# Breakfast & Brunch, Restaurants, Sandwiches, American (Traditional), Italian
# Sandwiches, Coffee & Tea, Breakfast & Brunch, Restaurants, Bagels, Food
# Bars, Beer Bar, Cocktail Bars, American (Traditional), Restaurants, Breakfast & Brunch, Nightlife
# Doctors, Naturopathic/Holistic, Reiki, Professional Services, Massage Therapy, Life Coach, Health & Medical
# Periodontists, Dentists, Endodontists, Keys & Locksmiths, Home Services, General Dentistry, Cosmetic Dentists, Health & Medical
# Doctors, Naturopathic/Holistic, Reiki, Professional Services, Massage Therapy, Life Coach, Health & Medical
# American (New), Pizza, American (Traditional), Restaurants
# Beauty & Spas, Massage
#
#
# User name: Paula
# ---------------------------------
# The resturant that the user visited:
# Food, Greek, Breakfast & Brunch, Restaurants, Sandwiches
# Nightlife, American (Traditional), Pizza, Restaurants
# Health & Medical, Acupuncture
# Kitchen & Bath, Building Supplies, Flooring, Home & Garden, Home Services, Shopping, Contractors
# Food, Restaurants, American (New), Seafood, American (Traditional), Ramen, Coffee & Tea, Sandwiches, Japanese
# Shopping, Antiques
# Shopping, Antiques
# Used, Vintage & Consignment, Men's Clothing, Shopping, Formal Wear, Fashion
# Greek, Italian, Mediterranean, Restaurants, Tapas/Small Plates
# American (Traditional), Bars, Sandwiches, Burgers, Irish, Nightlife, Restaurants, Pubs
#
#
# User name: Jason
# ---------------------------------
# The resturant that the user visited:
# Pizza, Restaurants
# Sandwiches, Restaurants, Food, Cheese Shops, Coffee & Tea, Specialty Food, Grocery, Juice Bars & Smoothies, Delis
# Comfort Food, Nightlife, Bars, Cocktail Bars, Restaurants, German
# Home Services, Professional Services, Local Services, Keys & Locksmiths, Security Systems
# Restaurants, Thai
#
#
# User name: Melissa
# ---------------------------------
# The resturant that the user visited:
# Day Spas, Beauty & Spas, Hair Salons
# Hair Salons, Beauty & Spas
# Specialty Food, Food, Restaurants, Ethnic Food, Dim Sum, Chinese
# Naturopathic/Holistic, Doctors, Health & Medical
# Restaurants, Ramen, Japanese
# Restaurants, Salad
# Day Spas, Makeup Artists, Hair Salons, Massage, Beauty & Spas
# Salad, Restaurants
# Steakhouses, Seafood, Canadian (New), Restaurants
# Fast Food, Burgers, Coffee & Tea, Food, Restaurants
#
#
# User name: Kenneth
# ---------------------------------
# The resturant that the user visited:
# Nightlife, Seafood, Bars, American (Traditional), American (New), Restaurants, Burgers
# Bars, Gluten-Free, Restaurants, American (Traditional), Nightlife, Vegetarian, Wine Bars, American (New), Seafood
# Home Cleaning, Office Cleaning, Professional Services, Window Washing, Home Services
# Home Cleaning, Office Cleaning, Professional Services, Window Washing, Home Services
# Dog Walkers, Pets, Pet Services, Pet Sitting
# Latin American, Barbeque, Restaurants, Southern, Ethnic Food, Meat Shops, Specialty Food, Food
# Restaurants, Italian, Pizza
# Food, Desserts, Ice Cream & Frozen Yogurt, Restaurants, Italian, Pizza
# Restaurants, Bars, Food, Indian, Nightlife, Halal, Wine Bars, Coffee & Tea
# Food, Desserts, Ice Cream & Frozen Yogurt, Restaurants, Italian, Pizza
# Indian, Salad, Desserts, Restaurants, Food
# Restaurants, Bars, Cocktail Bars, Breakfast & Brunch, Seafood, American (Traditional), Nightlife
#
#
# User name: Kim
# ---------------------------------
# The resturant that the user visited:
# Breakfast & Brunch, Gluten-Free, Beer, Wine & Spirits, American (New), American (Traditional), Vegetarian, Coffee & Tea, Burgers, Restaurants, Food
# Food, Desserts, Restaurants, Waffles, Ice Cream & Frozen Yogurt, Specialty Food, Breakfast & Brunch
# Eyewear & Opticians, Shopping, Urgent Care, Optometrists, Health & Medical
# Restaurants, Japanese, Sushi Bars
# Restaurants, Fast Food, American (New), Soul Food, Asian Fusion
# Wholesale Stores, Food, Grocery, Fashion, Department Stores, Shopping
# Food, Coffee & Tea
# Cocktail Bars, Nightlife, Bars, American (New), Restaurants, Breakfast & Brunch, Champagne Bars
# Bagels, American (Traditional), Coffee & Tea, Food, Bakeries, Restaurants, Donuts
# Restaurants, Cafes, Breakfast & Brunch, Food, Juice Bars & Smoothies, Coffee & Tea
#
#
# User name: Elizabeth
# ---------------------------------
# The resturant that the user visited:
# Restaurants, Bakeries, Vegan, Food, Vegetarian
# Coffee & Tea, Food, Delis, Desserts, Bakeries, Restaurants, Coffee Roasteries, Breakfast & Brunch
# Chicken Shop, Restaurants, Mexican, Steakhouses, Seafood
# Restaurants, Pizza
# Chocolatiers & Shops, Specialty Food, Desserts, Food
# Greek, Restaurants, Halal, Mediterranean, Middle Eastern
# Restaurants, American (New)
# Specialty Food, Breakfast & Brunch, Restaurants, Food, Mexican, Ethnic Food
# Comfort Food, Food, American (New), Vegan, Sandwiches, Restaurants, Bars, Desserts, American (Traditional), Nightlife
# Arts & Crafts, Framing, Shopping
# Nightlife, Pubs, Bars, Burgers, Restaurants
# Coffee & Tea, Desserts, Bakeries, Food
# Restaurants, Ethiopian
#
#
# User name: Evan
# ---------------------------------
# The resturant that the user visited:
# American (New), American (Traditional), Restaurants, Burgers
# Food Trucks, Restaurants, Mexican, Food
# Local Services, Junk Removal & Hauling, Self Storage, Home Services, Movers
# Seafood, American (New), Restaurants, Cajun/Creole, Food, Mexican, Food Stands
# Restaurants, American (Traditional)
# Turkish, Restaurants, Food Trucks, Food, Food Stands
# Men's Clothing, Shopping, Formal Wear, Local Services, Fashion, Sewing & Alterations, Event Planning & Services, Venues & Event Spaces
# Flooring, Contractors, Handyman, Carpenters, Home Services
# Flooring, Contractors, Handyman, Carpenters, Home Services
# Breakfast & Brunch, Mexican, Restaurants, Tex-Mex
#
#
# User name: James
# ---------------------------------
# The resturant that the user visited:
# Barbers, Beauty & Spas, Hair Salons, Hair Stylists
# Nightlife, Pubs, Restaurants, Bars
# Nightlife, Bars, Pubs, Food, Breweries
# Restaurants, Seafood, Sushi Bars, Steakhouses
# Restaurants, Food, Beer, Wine & Spirits, American (Traditional)
# Mexican, Lounges, Restaurants, Bars, Nightlife
# Restaurants, Nightlife, American (Traditional), Cocktail Bars, Gastropubs, Bars
# French, American (Traditional), Restaurants
# Modern European, Wine Bars, Mediterranean, Tapas Bars, Moroccan, Bars, Nightlife, Restaurants
# Pizza, Restaurants, Food, Italian
# Food, Nightlife, Bars, Arts & Entertainment, Performing Arts, American (Traditional), Belgian, Restaurants, Donuts, Pubs, Breweries, Greek
#
#
# User name: Omara
# ---------------------------------
# The resturant that the user visited:
# Oil Change Stations, Automotive
# Food, Coffee & Tea, Juice Bars & Smoothies, Bubble Tea
# Bakeries, Event Planning & Services, Food, Desserts
# Food, Restaurants, Bakeries
# Beauty & Spas, Nail Salons
# Brazilian, Restaurants
# Sandwiches, Breakfast & Brunch, Restaurants, Mexican
# Restaurants, Nightlife, Bars, Mexican
# Caterers, Ethnic Food, Restaurants, Mediterranean, International Grocery, Event Planning & Services, Food, Grocery, Specialty Food, Greek
# Transportation, Taxis, Hotels & Travel
# Specialty Food, Chocolatiers & Shops, Gift Shops, Food, Florists, Flowers & Gifts, Shopping
#
#
# User name: Dan
# ---------------------------------
# The resturant that the user visited:
# Italian, Restaurants
# Latin American, Restaurants, Nightlife, Bars, Cocktail Bars
# Caterers, Restaurants, Breakfast & Brunch, Southern, Event Planning & Services, Bakeries, Cajun/Creole, Food
# Food Stands, Restaurants, Sandwiches, Breakfast & Brunch
# Breweries, Food
# Real Estate, Hotels & Travel, Hotels, Event Planning & Services, Apartments, Home Services
# Hair Salons, Day Spas, Barbers, Nail Salons, Beauty & Spas, Hair Removal, Waxing
# Food, Coffee & Tea, Restaurants, Pizza, Breakfast & Brunch
# Local Services, Laundry Services, Dry Cleaning, Dry Cleaning & Laundry, Laundromat
# Restaurants, American (New), Tapas/Small Plates, Mexican
#
#
# User name: Pete
# ---------------------------------
# The resturant that the user visited:
# Restaurants, Pizza, Italian
# Restaurants, Mexican
# Food, Grocery, Drugstores, Shopping
# Yoga, Fitness & Instruction, Trainers, Gyms, Active Life, Sports Clubs
# Smog Check Stations, Automotive, Auto Repair, Auto Glass Services, Towing, Oil Change Stations
# Automotive, Auto Repair, Oil Change Stations
# Specialty Food, Food Stands, Tex-Mex, Food Trucks, Mexican, Food, Restaurants, Local Flavor, Fast Food, Breakfast & Brunch
# Thai, Asian Fusion, Restaurants
#
#
# User name: Erica
# ---------------------------------
# The resturant that the user visited:
# Local Services, Dry Cleaning, Sewing & Alterations, Dry Cleaning & Laundry, Laundry Services, Shoe Repair
# Beauty & Spas, Day Spas
# Pet Groomers, Pets, Pet Sitting, Pet Services
# Nail Salons, Beauty & Spas
# Event Planning & Services, Arts & Entertainment, Party & Event Planning, Arcades
# Restaurants, Seafood, Italian
# Plumbing, Heating & Air Conditioning/HVAC, Home Services
# Car Dealers, Auto Repair, Automotive
# Beauty & Spas, Hair Salons, Hair Stylists
# Food, Restaurants, Burgers
#
#
# User name: Brian
# ---------------------------------
# The resturant that the user visited:
# Health & Medical, Professional Services, Counseling & Mental Health
# Mediterranean, Halal, Middle Eastern, Indian, Restaurants, Buffets
# Dance Schools, Specialty Schools, Education, Active Life
# Health & Medical, Education, Naturopathic/Holistic, Educational Services, Vitamins & Supplements, Doctors, Counseling & Mental Health, Pediatricians, Shopping, Allergists, Nurse Practitioner, Gastroenterologist, Nutritionists
# Packing Services, Local Services, Movers, Self Storage, Home Cleaning, Home Services
# Packing Services, Local Services, Movers, Self Storage, Home Cleaning, Home Services
# Beauty & Spas, Hair Salons, Men's Hair Salons, Barbers
# Lawyers, Immigration Law, Professional Services, Legal Services
# Pet Sitting, Nightlife, Breweries, Distilleries, Tours, Local Flavor, Pet Services, Food, Transportation, Pedicabs, Hotels & Travel, Pets, Bars, Taxis, Pubs
# Auto Repair, Body Shops, Automotive
#
#
# User name: Jena
# ---------------------------------
# The resturant that the user visited:
# Nightlife, Cocktail Bars, Bars
# Restaurants, Breakfast & Brunch, French, Creperies, Salad
# Bars, Restaurants, Breakfast & Brunch, Dive Bars, Beer, Wine & Spirits, Burgers, Food, Vegan, Lounges, Sandwiches, Nightlife
# Breakfast & Brunch, Vegetarian, Cafes, Vegan, Restaurants
# Restaurants, Pizza
# Coffee & Tea, Restaurants, Food
# Bars, Sports Bars, Nightlife, Salad, Pizza, Restaurants
# Restaurants, Breakfast & Brunch, American (Traditional), Coffee & Tea, Food
# Salad, Japanese, Restaurants, Sushi Bars
# Restaurants, Soup, Sandwiches, Local Flavor, Delis
# Thai, Mexican, Restaurants
#
#
# User name: Lori
# ---------------------------------
# The resturant that the user visited:
# Japanese, Restaurants
# Restaurants, Brewpubs, Food, Breweries, Pizza, Nightlife, Pubs, Bars, Breakfast & Brunch, American (New), American (Traditional)
# Diners, Seafood, Thai, Restaurants, Gluten-Free, Vegetarian
#
#
# User name: John
# ---------------------------------
# The resturant that the user visited:
# Lounges, Cinema, Restaurants, Nightlife, Bars, Arts & Entertainment, American (New)
# Lounges, Cinema, Restaurants, Nightlife, Bars, Arts & Entertainment, American (New)
# Lounges, Cinema, Restaurants, Nightlife, Bars, Arts & Entertainment, American (New)
# Lounges, Cinema, Restaurants, Nightlife, Bars, Arts & Entertainment, American (New)
# Lounges, Cinema, Restaurants, Nightlife, Bars, Arts & Entertainment, American (New)
# Lounges, Cinema, Restaurants, Nightlife, Bars, Arts & Entertainment, American (New)
# Lounges, Cinema, Restaurants, Nightlife, Bars, Arts & Entertainment, American (New)
# Nightlife, Bars, Burgers, Restaurants
# Restaurants, Food, Pizza
# Restaurants, Italian, Nightlife, Bars
# Restaurants, Food, Pizza
# Restaurants, Italian, Nightlife, Bars
# Restaurants, Food, Pizza
# American (Traditional), Southern, Comfort Food, Restaurants, Seafood
# Waffles, Street Vendors, Specialty Food, Food Trucks, Caterers, Restaurants, Food Court, Event Planning & Services, Food
# Restaurants, Food Trucks, Breakfast & Brunch, Mexican, Food
# Nightlife, Pubs, Bars, Beer Bar, Event Planning & Services
# Coffee & Tea, Food
# American (Traditional), Salad, Restaurants, Diners, Sushi Bars, Japanese, Nightlife, Bars, Comfort Food
# Coffee & Tea, Food
# Sandwiches, Food Trucks, Restaurants, Food, American (Traditional)
# Cigar Bars, Pool Halls, Bars, Whiskey Bars, Arts & Entertainment, Music Venues, Nightlife
# Grocery, Food
#
#
# User name: Deb
# ---------------------------------
# The resturant that the user visited:
# Food, Diners, American (Traditional), Active Life, Donuts, Breakfast & Brunch, Restaurants
# Bars, Nightlife, American (New), Restaurants, Seafood
# Fashion, Children's Clothing, Men's Clothing, Women's Clothing, Shopping
# Bakeries, Food, Restaurants
# Chinese, American (Traditional), Restaurants
# American (Traditional), Diners, Restaurants, Breakfast & Brunch, Sandwiches
# Orthodontists, Dentists, Health & Medical, Oral Surgeons, General Dentistry
# Skin Care, Day Spas, Beauty & Spas, Massage, Health & Medical, Medical Spas
# Skin Care, Day Spas, Beauty & Spas, Massage, Health & Medical, Medical Spas
# Local Flavor, Donuts, Coffee & Tea, Food
# Physical Therapy, Sports Medicine, Health & Medical, Massage Therapy, Doctors
# Automotive, Towing
# Restaurants, Cafes
#
#
# User name: Kristen
# ---------------------------------
# The resturant that the user visited:
# Pizza, Italian, Restaurants, Mediterranean
# Vietnamese, Restaurants
# Spanish, Venues & Event Spaces, Seafood, American (Traditional), Restaurants, Event Planning & Services, American (New), Burgers
# Preschools, Local Services, Child Care & Day Care, Education
# Beauty & Spas, Cosmetic Surgeons, Dermatologists, Medical Spas, Doctors, Health & Medical
# Oil Change Stations, Automotive, Auto Repair
# Food, Vegetarian, Restaurants, American (New), Coffee & Tea, Tea Rooms
# Tex-Mex, Mexican, Restaurants
# Local Services, Active Life, Summer Camps, Kids Activities, Party & Event Planning, Child Care & Day Care, Event Planning & Services
# Child Care & Day Care, Local Services
# Chicken Wings, Restaurants, Sandwiches
# Caribbean, Brazilian, Restaurants, Puerto Rican, Sandwiches, Cuban
# Bagels, Sandwiches, Food, Restaurants, Delis
#
#
# User name: Sarah
# ---------------------------------
# The resturant that the user visited:
# Gas Stations, Tires, Auto Repair, Automotive
# Mexican, Restaurants
# Active Life, Parks
# Hair Removal, Beauty & Spas, Day Spas, Laser Hair Removal, Skin Care, Makeup Artists
# Real Estate, Property Management, Condominiums, Home Services, Homeowner Association
# Oil Change Stations, Car Dealers, Body Shops, Automotive, Auto Repair
# Day Spas, Hair Salons, Nail Salons, Massage, Beauty & Spas
# American (New), Barbeque, Nightlife, Restaurants
# Restaurants, Cafes, Breakfast & Brunch
# Caterers, Event Planning & Services, Restaurants, Barbeque
#
#
# User name: Ian
# ---------------------------------
# The resturant that the user visited:
# Professional Services, Heating & Air Conditioning/HVAC, Air Duct Cleaning, Appliances & Repair, Home Services, Local Services, Plumbing
# Professional Services, Heating & Air Conditioning/HVAC, Air Duct Cleaning, Appliances & Repair, Home Services, Local Services, Plumbing
# Diagnostic Imaging, Health & Medical, Doctors, Laboratory Testing, Radiologists, Diagnostic Services, Medical Centers, Vascular Medicine
# Restaurants, Italian, Pizza
# Medical Centers, Laboratory Testing, Doctors, Vascular Medicine, Health & Medical, Diagnostic Imaging, Cardiologists, Radiologists, Diagnostic Services
# Urologists, Health & Medical, Medical Centers, Doctors
# Auto Repair, Automotive
# Oral Surgeons, General Dentistry, Health & Medical, Dentists
# Dentists, Periodontists, Cosmetic Dentists, Health & Medical, Oral Surgeons, General Dentistry
# Doctors, Ear Nose & Throat, Health & Medical
# Dentists, Periodontists, Cosmetic Dentists, Health & Medical, Oral Surgeons, General Dentistry
#
#
# User name: Jurgen
# ---------------------------------
# The resturant that the user visited:
# Automotive, Car Dealers, Body Shops, Auto Repair, Auto Parts & Supplies
# Automotive, Car Dealers, Body Shops, Auto Repair, Auto Parts & Supplies
# Restaurants, Greek, Mediterranean
# Restaurants, Bubble Tea, Thai, Food, Vegan
#
#
# User name: Chandra
# ---------------------------------
# The resturant that the user visited:
# Soup, Asian Fusion, Pan Asian, Vietnamese, Food, Thai, Chinese, Restaurants, Sandwiches, Coffee & Tea
#
#
# User name: Tiffany
# ---------------------------------
# The resturant that the user visited:
# Food, Ice Cream & Frozen Yogurt
# Gluten-Free, Italian, American (Traditional), American (New), Caterers, Salad, Food, Wine Bars, Bars, Nightlife, Specialty Food, Sandwiches, Restaurants, Event Planning & Services
# Home Cleaning, Carpet Cleaning, Home Services, Local Services, Pressure Washers, Carpeting, Damage Restoration, Air Duct Cleaning
# Tree Services, Home Services
# Coffee & Tea, Food, Cafes, Restaurants
# Desserts, Ice Cream & Frozen Yogurt, Food
# Restaurants, Breakfast & Brunch, American (New), Salad
# Desserts, Coffee & Tea, Restaurants, Food, Patisserie/Cake Shop, Breakfast & Brunch, Donuts, Bakeries, Cafes
# Delis, Restaurants, Sandwiches, Fast Food
# Delis, American (New), Event Planning & Services, Caterers, Restaurants, Food, Barbeque, Smokehouse, Desserts
# Garage Door Services, Home Services, Contractors
# Restaurants, Pizza, Italian, Sandwiches, Chicken Wings
# Home & Garden, Pest Control, Shopping, Local Services, Insulation Installation, Wildlife Control, Home Services
# Restaurants, Desserts, Bakeries, Vegan, Food
# Health & Medical, Nail Salons, Massage Therapy, Permanent Makeup, Beauty & Spas, Day Spas, Hair Removal, Massage, Waxing
#
#
# User name: Victoria
# ---------------------------------
# The resturant that the user visited:
# American (Traditional), Restaurants
# Beauty & Spas, Hair Salons, Barbers
# American (Traditional), Restaurants
# Greek, Restaurants
# Massage, Day Spas, Laser Hair Removal, Nail Salons, Skin Care, Hair Removal, Beauty & Spas
# Pet Stores, Pets, Pet Services
# Pet Stores, Pets
# Caterers, Beer, Wine & Spirits, Food, Bakeries, Event Planning & Services, Cafes, Coffee & Tea, Restaurants, Breakfast & Brunch
# Pet Services, Pets, Pet Groomers
# Shopping, Discount Store, Thrift Stores
# Tapas/Small Plates, Restaurants, Tapas Bars, Spanish
# Pet Services, Pet Stores, Pets
#
#
# User name: Ed
# ---------------------------------
# The resturant that the user visited:
# Florists, Flowers & Gifts, Shopping
# Health & Medical, Massage Therapy, Massage, Beauty & Spas
# Bars, Grocery, American (Traditional), CSA, Sandwiches, Restaurants, American (New), Food, Coffee & Tea, Nightlife, Event Planning & Services, Venues & Event Spaces, Specialty Food
# Nightlife, Seafood, Bars, Food, Restaurants
# Restaurants, Beer, Wine & Spirits, Food, Burgers, American (New)
# Keys & Locksmiths, Home Services
# Restaurants, Mexican, Food
# Auto Repair, Automotive
# Contractors, Carpenters, Home Services, Windows Installation
# Japanese, Asian Fusion, Chinese, Sushi Bars, Restaurants
# Breakfast & Brunch, American (New), Nightlife, Bars, Restaurants, Wine Bars, Pasta Shops, Specialty Food, Italian, Pizza, Tapas/Small Plates, Food
# Printing Services, Screen Printing, Local Services, Screen Printing/T-Shirt Printing
#
#
# User name: Nessa
# ---------------------------------
# The resturant that the user visited:
# Seafood, Mexican, Restaurants
# Hotels & Travel, Event Planning & Services, Hotels
# Beauty & Spas, Nail Salons, Hair Salons
# Steakhouses, Food, Ethnic Food, Japanese, Sushi Bars, Restaurants, Specialty Food
# Restaurants, Chicken Wings, Fast Food
# Steakhouses, Food, Ethnic Food, Japanese, Sushi Bars, Restaurants, Specialty Food
# Restaurants, Chinese
# Pets, Emergency Pet Hospital, Veterinarians, Pet Services
# Discount Store, Shopping
# Auto Parts & Supplies, Auto Repair, Automotive, Oil Change Stations, Tires
#
#
# User name: Susan
# ---------------------------------
# The resturant that the user visited:
# Tex-Mex, Restaurants, Mexican
# Home Services, Movers, Local Services, Packing Services, Self Storage
# Sandwiches, Desserts, Beer, Wine & Spirits, Restaurants, Food Delivery Services, Pizza, Food, Italian, Breakfast & Brunch
# Sandwiches, Desserts, Beer, Wine & Spirits, Restaurants, Food Delivery Services, Pizza, Food, Italian, Breakfast & Brunch
# Home Services, Garage Door Services
# Sandwiches, Desserts, Beer, Wine & Spirits, Restaurants, Food Delivery Services, Pizza, Food, Italian, Breakfast & Brunch
# Toy Stores, Shopping
# Restaurants, Pizza
# American (Traditional), Pubs, Nightlife, Restaurants, Burgers, Bars, American (New), Cocktail Bars
# Restaurants, American (Traditional), Diners, Breakfast & Brunch, French
# Chinese, Restaurants
# Chinese, Restaurants
# Fast Food, Burgers, Restaurants
#
#
# User name: Whitney
# ---------------------------------
# The resturant that the user visited:
# Lounges, Cinema, Restaurants, Nightlife, Bars, Arts & Entertainment, American (New)
# Restaurants, Nightlife, Beer, Wine & Spirits, Bars, Breakfast & Brunch, Food, Seafood, American (New), Cocktail Bars
# Bakeries, Restaurants, Bagels, Coffee & Tea, Food
# Restaurants, Specialty Food, Food Trucks, Italian, Food, Pasta Shops
# Event Planning & Services, Event Photography, Photo Booth Rentals, Nightlife, Party Equipment Rentals, Photographers, DJs
# Nail Salons, Beauty & Spas
# Sports Clubs, Event Planning & Services, Nightlife, Active Life, Axe Throwing, Arts & Entertainment, Venues & Event Spaces
# Food, Coffee & Tea
# Florists, Party & Event Planning, Shopping, Flowers & Gifts, Wedding Planning, Event Planning & Services
# Tapas/Small Plates, American (New), Wine Bars, Gluten-Free, American (Traditional), Restaurants, Food, Bars, Desserts, Nightlife, Cocktail Bars
#
#
# User name: Gina
# ---------------------------------
# The resturant that the user visited:
# Chinese, Sushi Bars, Japanese, Seafood, Hot Pot, Asian Fusion, Restaurants, Szechuan
# Chinese, Sushi Bars, Japanese, Seafood, Hot Pot, Asian Fusion, Restaurants, Szechuan
# Brazilian, Breakfast & Brunch, Italian, Restaurants
# Bakeries, Food, Restaurants
# American (New), Restaurants
# Bakeries, Food, Restaurants
# Laundry Services, Dry Cleaning & Laundry, Local Services
# Teeth Whitening, Cosmetic Dentists, Health & Medical, Beauty & Spas, General Dentistry, Dentists, Pediatric Dentists
# Food, Seafood, Portuguese, Restaurants, Desserts
# Pizza, Restaurants, Italian
# Restaurants, Pakistani, Indian
# Breakfast & Brunch, American (New), Burgers, American (Traditional), Italian, Restaurants, French
# Seafood, Restaurants
# Discount Store, Department Stores, Fashion, Shopping
# Discount Store, Department Stores, Fashion, Shopping
#
#
# User name: Tyler
# ---------------------------------
# The resturant that the user visited:
# Food Trucks, Ice Cream & Frozen Yogurt, Food
# Ethnic Grocery, International Grocery, Food, Grocery, Specialty Food, Imported Food, Ethnic Food
# Coffee & Tea, Restaurants, Donuts, Food, Breakfast & Brunch
# Food Trucks, Restaurants, Mexican, Food
# Salad, Desserts, Vegan, Food, Restaurants, Ethiopian, Gluten-Free
# Shopping, Bikes, Sporting Goods
# Grocery, Food
# Bars, Tapas/Small Plates, Lounges, Nightlife, Noodles, Vietnamese, Restaurants, Cocktail Bars
# Himalayan/Nepalese, Food Stands, Food Trucks, Restaurants, Food
# Shopping, Sporting Goods, Bikes
#
#
# User name: Sara
# ---------------------------------
# The resturant that the user visited:
# Breweries, Food, Brewpubs, Beer Gardens, American (New), Nightlife, Salad, Pubs, Sandwiches, Restaurants, Bars, Beer, Wine & Spirits, Gastropubs, Burgers
# Food, Restaurants, Beer Bar, Breakfast & Brunch, Nightlife, Cafes, Beer, Wine & Spirits, Bakeries, Bars, Coffee & Tea
# Cocktail Bars, Nightlife, Bars, Lounges
# Arts & Entertainment, Art Galleries, Colleges & Universities, Public Services & Government, Libraries, Shopping, Education, Museums
# Hair Removal, Nail Salons, Waxing, Skin Care, Beauty & Spas
# Fitness & Instruction, Barre Classes, Active Life
# Breakfast & Brunch, American (Traditional), Sandwiches, Restaurants, Food, Coffee & Tea
# Fitness & Instruction, Active Life, Massage, Beauty & Spas, Yoga, Meditation Centers
# Event Planning & Services, DJs, Arts & Entertainment
# Wedding Planning, Tex-Mex, Event Planning & Services, Venues & Event Spaces, Seafood, Restaurants, American (Traditional), Breakfast & Brunch, Local Flavor
# Active Life, Trainers, Fitness & Instruction, Gyms
#
#
# User name: R
# ---------------------------------
# The resturant that the user visited:
# American (Traditional), Restaurants
# Event Planning & Services, Farmers Market, Venues & Event Spaces, Food
# Bagels, Cafes, Restaurants, Desserts, Coffee & Tea, Food
# Pet Training, Pets, Pet Services, Veterinarians
# Do-It-Yourself Food, Food, Restaurants, Breakfast & Brunch
# Food, Farmers Market
# Local Services, Home Automation, Heating & Air Conditioning/HVAC, Home Services, Air Duct Cleaning
# Restaurants, Vegan, Delis, Live/Raw Food, Vegetarian
# Pets, Veterinarians
# Active Life, Yoga, Fitness & Instruction
# Lebanese, Restaurants, Middle Eastern
# Vegan, Bakeries, Coffee & Tea, Food, Shopping, Restaurants
# Diners, Vegan, Restaurants, Vegetarian, Gluten-Free, Breakfast & Brunch, Sandwiches
# Pet Stores, Pets
# Cafes, Bars, Nightlife, Burgers, Breakfast & Brunch, Restaurants, Vegan, Vegetarian
#
#
# User name: David
# ---------------------------------
# The resturant that the user visited:
# Financial Services, Banks & Credit Unions
# Local Flavor, Hotels & Travel, Tours
# Pubs, American (Traditional), Restaurants, Bars, Whiskey Bars, Barbeque, Nightlife, Southern
# Hair Salons, Barbers, Beauty & Spas
# Automotive, Car Wash
# Parks, Sports Clubs, Active Life
# Food, Pets, Coffee & Tea, Pet Training, Pet Sitting, Pet Services, Education
# Food, Food Trucks, Restaurants, Pizza
# Restaurants, Thai
#
#
# User name: Caroline
# ---------------------------------
# The resturant that the user visited:
# Latin American, American (New), Restaurants
# Chinese, Bubble Tea, Food, Restaurants
# Cuban, Restaurants
# Beauty & Spas, Hair Salons, Massage
# Restaurants, Food, Coffee & Tea
# Japanese, Seafood, Asian Fusion, Restaurants, Sushi Bars
# Indian, Restaurants
# Home Services, Gardeners, Irrigation, Local Services, Masonry/Concrete, Tree Services, Landscaping
# Restaurants, Food Delivery Services, Food, Chinese
# Restaurants, Gluten-Free, Diners, American (Traditional), American (New)
# Thai, Restaurants
#
#
# User name: Tracey
# ---------------------------------
# The resturant that the user visited:
# Nightlife, Wine Bars, Restaurants, Mexican, Bars, Beer Bar
# Gastropubs, Beer, Wine & Spirits, Restaurants, American (New), Food
# Health & Medical, Chiropractors
# American (New), Restaurants, Wine Bars, Bars, Beer Bar, Gastropubs, Nightlife
# Restaurants, Event Planning & Services, Food, Breakfast & Brunch, Desserts, American (New), Bagels, Southern, Caterers, Bars, Coffee & Tea, Nightlife, Cafes, Wine Bars
# Restaurants, American (New), Sandwiches, Breakfast & Brunch, Diners
# Restaurants, Cafes, American (New), French, Italian
# Restaurants, American (Traditional)
# Food, Caterers, Event Planning & Services, Bakeries
# Specialty Food, Nightlife, Restaurants, Mexican, New Mexican Cuisine, Food, American (New), Bars, Cocktail Bars, Tex-Mex
# Southern, Restaurants, American (New)
# Tapas/Small Plates, Tapas Bars, Restaurants, Spanish
# Pizza, Restaurants
#
#
# User name: David
# ---------------------------------
# The resturant that the user visited:
# Restaurants, Fast Food, Food, Sandwiches, Food Trucks, Burgers
# Restaurants, Food Trucks, Food Stands, Food, Middle Eastern, Persian/Iranian, Mediterranean
# Local Flavor, Food Stands, Sandwiches, Food, Street Vendors, Restaurants
# Japanese, Restaurants, Food, Food Stands, Sushi Bars, Street Vendors
# Japanese, Restaurants, Food, Food Stands, Sushi Bars, Street Vendors
# American (Traditional), Fast Food, Burgers, Restaurants
# Shopping, Doctors, Eyewear & Opticians, Health & Medical, Optometrists, Laser Eye Surgery/Lasik
# Mexican, Restaurants
# Barbeque, Sandwiches, Food Stands, Restaurants, Food
# Hair Removal, Beauty & Spas, Massage, Hair Stylists, Hair Salons, Barbers
# Restaurants, Food Trucks, Mexican, Food, Food Stands
# Restaurants, Bubble Tea, Food Trucks, Thai, Food Stands, Food, Street Vendors
#
#
# User name: Susan
# ---------------------------------
# The resturant that the user visited:
# Nail Salons, Beauty & Spas
# Massage Therapy, Weight Loss Centers, Health & Medical, Chiropractors
# Sandwiches, Breakfast & Brunch, Restaurants, Juice Bars & Smoothies, Food, Soup
# Salad, Pizza, Sandwiches, Restaurants
# Waxing, Makeup Artists, Beauty & Spas, Cosmetics & Beauty Supply, Rolfing, Day Spas, Nail Salons, Hair Removal, Massage, Eyebrow Services, Skin Care, Shopping
# Hair Extensions, Hair Salons, Hair Stylists, Beauty & Spas
# Restaurants, Thai
#
#
# User name: Nick
# ---------------------------------
# The resturant that the user visited:
# Shopping, Watch Repair, Watches, Local Services
# Bicycles, Active Life, Bike Shop, Bike Rentals, Bike Repair/Maintenance, Cycling Classes, Mountain Biking, Local Services, Sporting Goods, Shopping, Bikes
# Shopping, Watch Repair, Watches, Local Services
# Sewing & Alterations, Local Services, Laundry Services, Dry Cleaning & Laundry
# Sporting Goods, Active Life, Bike Rentals, Bikes, Local Services, Shopping, Bike Repair/Maintenance
# Optometrists, Health & Medical
# Sandwiches, Salad, Event Planning & Services, Food, Cheesesteaks, Restaurants, Caterers, Italian
# Home Services, Real Estate Services, Real Estate
# Sewing & Alterations, Laundry Services, Local Services, Dry Cleaning & Laundry
# Jewelry, Shopping
# Restaurants, Jazz & Blues, Piano Bars, Japanese, Sushi Bars, Nightlife, Asian Fusion, Arts & Entertainment, Thai
#
#
# User name: mariam
# ---------------------------------
# The resturant that the user visited:
# Beauty & Spas, Yoga, Health & Medical, Pilates, Acupuncture, Massage, Active Life, Fitness & Instruction, Trainers
# Chinese, Asian Fusion, Restaurants, Sushi Bars, Japanese
# Caterers, Barbeque, Event Planning & Services, Restaurants
# Hair Removal, Massage, Cosmetics & Beauty Supply, Shopping, Beauty & Spas, Waxing, Nail Salons
# Middle Eastern, Restaurants, Food, Bakeries
# Food, Donuts, Restaurants, Coffee & Tea, Breakfast & Brunch
# Seafood, Restaurants, American (New), Bars, Nightlife, Cocktail Bars
# Restaurants, Pizza
# Nightlife, American (Traditional), American (New), Restaurants, Bars
# Local Services, Shoe Repair
# Bakeries, Food, Restaurants, Desserts
# Seafood, Restaurants, Sushi Bars, Japanese
# Nightlife, Wine Bars, Steakhouses, Bars, American (Traditional), Seafood, Restaurants
# Restaurants, Nightlife, Tapas/Small Plates, American (Traditional), Bars, Coffee & Tea, Food, American (New), Breakfast & Brunch, Bakeries
# Restaurants, Chinese
# Diners, Caribbean, Local Flavor, Greek, Breakfast & Brunch, Restaurants, French
#
#
# User name: Jamie
# ---------------------------------
# The resturant that the user visited:
# Coffee Roasteries, Coffee & Tea, Food
# Restaurants, Gluten-Free, Coffee & Tea, Juice Bars & Smoothies, Food, Breakfast & Brunch
# Tires, Oil Change Stations, Smog Check Stations, Automotive, Auto Repair
# Automotive, Auto Parts & Supplies, Auto Repair, Oil Change Stations, Tires
# Dive Bars, Bars, Restaurants, Coffee & Tea, Beer Gardens, Nightlife, Breakfast & Brunch, Beer, Wine & Spirits, Cheesesteaks, Barbeque, Lounges, Food
# Optometrists, Health & Medical
# Restaurants, Coffee & Tea, Cafes, Wine Bars, Breakfast & Brunch, Nightlife, Food, Bars
# Bars, Nightlife, Italian, Food, Restaurants, Pizza
# Eyelash Service, Skin Care, Beauty & Spas, Hair Extensions, Hair Salons, Barbers
# Smog Check Stations, Oil Change Stations, Auto Repair, Auto Parts & Supplies, Automotive, Commercial Truck Repair, Transmission Repair
# Chinese, Restaurants, Noodles, Bars, Vietnamese, Nightlife
# Smog Check Stations, Oil Change Stations, Auto Repair, Auto Parts & Supplies, Automotive, Commercial Truck Repair, Transmission Repair
# Nightlife, Vegetarian, Wine Bars, Bars, American (New), Restaurants
# Dentists, Cosmetic Dentists, Orthodontists, Health & Medical, General Dentistry, Oral Surgeons
#
#
# User name: Jason
# ---------------------------------
# The resturant that the user visited:
# Restaurants, Sandwiches, Nightlife, Breakfast & Brunch, German, Beer, Wine & Spirits, Food, Beer Gardens, Desserts, Bars
# Steakhouses, Restaurants, Japanese, Sushi Bars
# Restaurants, Noodles, Japanese, Soup, Ramen
# Laser Eye Surgery/Lasik, Optometrists, Ophthalmologists, Health & Medical, Doctors
# Sandwiches, Restaurants
# Colombian, Vegetarian, Bars, Juice Bars & Smoothies, Latin American, Food, Nightlife, Hot Dogs, Restaurants, Burgers
# Tobacco Shops, Nightlife, Lounges, Shopping, Bars
# Food, Desserts, Salad, Restaurants, Sandwiches, Cajun/Creole
# Coffee & Tea, Restaurants, Wine Bars, American (Traditional), Cocktail Bars, Nightlife, Bars, Breakfast & Brunch, Salad, Tapas/Small Plates, American (New), Italian, Food
# Massage Therapy, Massage, Health & Medical, Chiropractors, Beauty & Spas
# Restaurants, Italian, Sandwiches, Delis, Soup
#
#
# User name: Inga
# ---------------------------------
# The resturant that the user visited:
# International Grocery, Restaurants, Delis, Russian, Food, Grocery
# American (Traditional), Restaurants, Vegan, German, Breakfast & Brunch
# Restaurants, Pizza
# Sports Wear, Barre Classes, Active Life, Shopping, Gyms, Fashion, Sporting Goods, Fitness & Instruction
# Breakfast & Brunch, Restaurants, Bars, Vegetarian, Nightlife, Pizza, Vegan, Gluten-Free, Food, Coffee & Tea
# Vegan, Gluten-Free, Caterers, Live/Raw Food, Event Planning & Services, Food, Desserts, Restaurants
# Food, Chocolatiers & Shops, Candy Stores, Hotels & Travel, Food Tours, Tours, Ice Cream & Frozen Yogurt, Specialty Food
# Shopping, Beer, Wine & Spirits, Grocery, Food, Flowers & Gifts, Florists
# Cafes, Restaurants, Coffee Roasteries, Food, Coffee & Tea
# Auto Parts & Supplies, Auto Repair, Tires, Automotive
# Restaurants, Coffee & Tea, Coffee Roasteries, Cafes, Food
# Restaurants, Food, Food Trucks, Asian Fusion, Sushi Bars
# Restaurants, Cafes, Breakfast & Brunch, Food, Juice Bars & Smoothies, Coffee & Tea
#
#
# User name: amy
# ---------------------------------
# The resturant that the user visited:
# Bubble Tea, Food, Vietnamese, Restaurants, Sandwiches
# Appliances, Shopping, Home & Garden, Local Services, Professional Services, Appliances & Repair
# Breakfast & Brunch, Beer Bar, Restaurants, Nightlife, Bars, Food, Comfort Food, Beer, Wine & Spirits, American (New)
# Automotive, Tires, Auto Repair, Auto Glass Services
# General Dentistry, Doctors, Dentists, Health & Medical
# Fish & Chips, British, Restaurants
# Tires, Automotive, Auto Repair
# Salad, Bars, Burgers, Restaurants, Event Planning & Services, Venues & Event Spaces, Wine Bars, Nightlife, American (Traditional), Beer Bar
# Asian Fusion, Bars, Nightlife, Restaurants, Beer Bar, Beer Gardens, American (New), Sports Bars, Food Court
# Sandwiches, American (New), Food, Coffee & Tea, Restaurants, Breakfast & Brunch
# Payroll Services, Financial Services, Tax Services, Accountants, Professional Services
#
#
# User name: Tim
# ---------------------------------
# The resturant that the user visited:
# Dance Clubs, Bars, American (Traditional), Restaurants, Arts & Entertainment, Nightlife, Breakfast & Brunch, Music Venues
# French, Cambodian, Restaurants
# Caterers, Indian, Buffets, Event Planning & Services, Pakistani, Restaurants
# Food, Bakeries, Coffee & Tea, Ice Cream & Frozen Yogurt
# Appliances, Appliances & Repair, Shopping, Local Services, Home & Garden
# Restaurants, Breakfast & Brunch, Bakeries, Coffee & Tea, Bagels, Food
# Fitness & Instruction, Trainers, Dentists, Active Life, Oral Surgeons, Pediatric Dentists, Health & Medical, Cosmetic Dentists, General Dentistry
# Restaurants, Chinese
# Massage, Health & Medical, Acupuncture, Reiki, Physical Therapy, Massage Therapy, Beauty & Spas
# Nightlife, Diners, Bars, Breakfast & Brunch, Restaurants
# Restaurants, Food, Bakeries
# Diagnostic Imaging, Diagnostic Services, Health & Medical
# Sandwiches, Shopping, Coffee & Tea, Nightlife, Tapas Bars, Bars, Music Venues, Art Galleries, Latin American, Cafes, Arts & Entertainment, Food, Restaurants
# Vegan, Vegetarian, Nightlife, Food, Bars, Internet Cafes, Restaurants, Thai, Coffee & Tea, Sushi Bars
#
#
# User name: Barb
# ---------------------------------
# The resturant that the user visited:
# Medical Centers, Health & Medical, Doctors, Urgent Care
# Dentists, General Dentistry, Cosmetic Dentists, Health & Medical
# Self Storage, Movers, Home Services, Local Services
# Restaurants, American (Traditional), Italian, Breakfast & Brunch, Salad
# Contractors, Local Services, Home Services, Home Inspectors
# American (Traditional), Restaurants, Breakfast & Brunch, Gluten-Free
# Pizza, Restaurants, Salad, American (Traditional), Sandwiches
# American (New), Comfort Food, Restaurants, Breakfast & Brunch
# Local Services, Apartments, Nurseries & Gardening, Sporting Goods, Appliances & Repair, Real Estate, Home & Garden, Home Services, Shopping, Bikes
# Breakfast & Brunch, Bakeries, Donuts, Food, Restaurants, Coffee & Tea
# Restaurants, Mexican, Nightlife, Local Flavor, Cocktail Bars, Spanish, Breakfast & Brunch, Tacos, Cafes, Bars
# Restaurants, Chinese, Asian Fusion
# Popcorn Shops, Gift Shops, Party Supplies, Grocery, Food, Event Planning & Services, Specialty Food, Candy Stores, Shopping, Flowers & Gifts
#
#
# User name: Allison
# ---------------------------------
# The resturant that the user visited:
# Restaurants, Nightlife, Pubs, Bars, Irish
# Tires, Auto Repair, Automotive, Transmission Repair, Oil Change Stations
# Desserts, Cocktail Bars, Food, American (New), American (Traditional), Bars, Comfort Food, Restaurants, Nightlife, Canadian (New)
# Hotels & Travel, Airport Shuttles, Transportation, Taxis
# Vegan, Restaurants, Salad, Ice Cream & Frozen Yogurt, Pizza, Food
# Coffee & Tea, Sandwiches, Event Planning & Services, British, Caterers, Restaurants, Food
# Restaurants, Thai
#
#
# User name: Cindy
# ---------------------------------
# The resturant that the user visited:
# Beauty & Spas, Doctors, Skin Care, Dermatologists, Health & Medical, Laser Hair Removal, Cosmetic Surgeons, Medical Spas, Hair Removal
# Beauty & Spas, Doctors, Skin Care, Dermatologists, Health & Medical, Laser Hair Removal, Cosmetic Surgeons, Medical Spas, Hair Removal
# Beauty & Spas, Doctors, Skin Care, Dermatologists, Health & Medical, Laser Hair Removal, Cosmetic Surgeons, Medical Spas, Hair Removal
# Pizza, Restaurants, Italian
# Soup, Cocktail Bars, French, American (New), Nightlife, Sandwiches, Brasseries, Salad, Burgers, Restaurants, Bars
# Shoe Repair, Local Services
# Car Dealers, Auto Repair, Automotive, Auto Parts & Supplies
# Restaurants, American (New)
# Restaurants, Italian
# Wine Bars, Diners, Restaurants, Southern, Nightlife, American (New), Bars, Breakfast & Brunch
# Medical Centers, Urgent Care, Doctors, Health & Medical
# Home Services, Heating & Air Conditioning/HVAC
# Italian, Breakfast & Brunch, Restaurants, Vegetarian
# Home Services, Heating & Air Conditioning/HVAC
#
#
# User name: Celeste
# ---------------------------------
# The resturant that the user visited:
# Specialty Food, Restaurants, Food, Fruits & Veggies, Vegan, Ice Cream & Frozen Yogurt, Food Stands
# Restaurants, Mexican, Hawaiian, Seafood, Food, Beer, Wine & Spirits, Fish & Chips
# Lounges, Restaurants, Cocktail Bars, American (New), Bars, Nightlife
# Food, Donuts
# Basque, Spanish, Tapas Bars, Restaurants
# Home Services, Professional Services, IT Services & Computer Repair, Internet Service Providers, Web Design, Local Services, Telecommunications
# Nail Salons, Beauty & Spas, Hair Removal, Skin Care
# Plumbing, Handyman, Contractors, Water Heater Installation/Repair, Lighting Fixtures & Equipment, Home Services
# Vietnamese, Restaurants, Coffee & Tea, Bars, Bakeries, Nightlife, Breakfast & Brunch, French, Food
# Food, Beer, Wine & Spirits, Nightlife, Wine Bars, Bars
# Nightlife, Vegetarian, Wine Bars, Bars, American (New), Restaurants
# Insurance, Financial Services
# Sushi Bars, Ramen, Food, Breakfast & Brunch, Restaurants, American (New), Japanese
#
#
# User name: David
# ---------------------------------
# The resturant that the user visited:
# Restaurants, American (New), American (Traditional)
# Desserts, Ethiopian, Vegetarian, Restaurants, Sandwiches, Food, Active Life, Sports Clubs
# Desserts, Ethiopian, Vegetarian, Restaurants, Sandwiches, Food, Active Life, Sports Clubs
# Desserts, Ethiopian, Vegetarian, Restaurants, Sandwiches, Food, Active Life, Sports Clubs
# Vape Shops, Electronics, Tobacco Shops, Shopping
# Mexican, Restaurants, Tex-Mex, Seafood
# Mexican, Restaurants, Tex-Mex, Seafood
# Vegetarian, Nightlife, Restaurants, Pizza, Bars, Sandwiches
# Ramen, Restaurants, Noodles, Japanese, Tapas/Small Plates
# Chicken Shop, American (New), Japanese, Restaurants
# Active Life, Aquariums
# Burgers, Gastropubs, Restaurants, American (New)
# Cafes, Bakeries, Restaurants, Food, Desserts
# Skin Care, Doctors, Laser Hair Removal, Beauty & Spas, Medical Spas, Dermatologists, Hair Removal, Health & Medical
# Skin Care, Doctors, Laser Hair Removal, Beauty & Spas, Medical Spas, Dermatologists, Hair Removal, Health & Medical
#
#
# User name: Adam
# ---------------------------------
# The resturant that the user visited:
# Local Services, Appliances & Repair
# American (New), American (Traditional), Restaurants, Burgers
# Local Flavor, Salad, Sandwiches, Restaurants, Barbeque, Food, Food Stands
# Breakfast & Brunch, Mexican, Caterers, Event Planning & Services, Restaurants, Tacos, Seafood, Food
# Seafood, American (New), Restaurants, Cajun/Creole, Food, Mexican, Food Stands
# Ice Cream & Frozen Yogurt, Food, Pizza, Restaurants, Sandwiches
# American (New), Cafes, Breakfast & Brunch, Restaurants, Diners
# Restaurants, Barbeque
# Buses, Hotels & Travel, Transportation
# Fashion, Shopping, Sporting Goods, Bikes, Sports Wear
# Home Services, Plumbing
#
#
# User name: Jennifer
# ---------------------------------
# The resturant that the user visited:
# Restaurants, Cocktail Bars, Nightlife, Lounges, Bars
# Shopping, Books, Mags, Music & Video, Toy Stores, Used Bookstore, Bookstores
# Restaurants, Mexican
# Bakeries, Nightlife, Cafes, Breakfast & Brunch, Food, Bars, Desserts, Restaurants
# Home Services, Painters
# Coffee & Tea, Food
# Hair Salons, Beauty & Spas, Blow Dry/Out Services, Hair Removal, Men's Hair Salons, Skin Care, Waxing
# Middle Schools & High Schools, Elementary Schools, Education
# Middle Schools & High Schools, Elementary Schools, Education
# Japanese, Restaurants, Sushi Bars
#
#
# User name: Kat
# ---------------------------------
# The resturant that the user visited:
# Dance Clubs, Bars, American (Traditional), Restaurants, Arts & Entertainment, Nightlife, Breakfast & Brunch, Music Venues
# Food, Ice Cream & Frozen Yogurt, Coffee & Tea, Juice Bars & Smoothies
# Beauty & Spas, Hair Salons, Hair Removal, Waxing, Makeup Artists
# Beauty & Spas, Hair Salons, Hair Removal, Waxing, Makeup Artists
# Apartments, Real Estate, Real Estate Services, Real Estate Agents, Home Services
# Tapas Bars, Cocktail Bars, Event Planning & Services, Pop-Up Restaurants, Tapas/Small Plates, Cafes, Italian, Restaurants, Nightlife, Bars, Venues & Event Spaces, Wine Bars, Lounges, Mediterranean
# Restaurants, Sandwiches, Food, Coffee & Tea, Bagels, Breakfast & Brunch
# Nail Salons, Beauty & Spas
# Nail Salons, Beauty & Spas
# Reiki, Life Coach, Health & Medical, Professional Services, Massage Therapy, Physical Therapy, Arts & Entertainment, Career Counseling, Supernatural Readings
# Restaurants, Diners, Breakfast & Brunch, Mediterranean, Middle Eastern
#
#
# User name: Ms
# ---------------------------------
# The resturant that the user visited:
# Mexican, American (Traditional), Breakfast & Brunch, Restaurants
# Shopping, Home Services, Interior Design, Home Decor, Furniture Stores, Mattresses, Home & Garden
# Vape Shops, Shopping, Tobacco Shops, Head Shops
# Restaurants, Bars, Mexican, Nightlife
# Coffee & Tea, Food, Donuts
# Burgers, Restaurants
# Meat Shops, Specialty Food, Persian/Iranian, Mediterranean, Ethnic Food, Food, Restaurants, Delis, Grocery, International Grocery, Middle Eastern
# Beauty & Spas, Nail Salons, Skin Care, Hair Removal, Day Spas
# Nail Salons, Beauty & Spas, Day Spas, Hair Salons
# Restaurants, Italian, Pizza
# Mexican, Bars, Tex-Mex, Nightlife, Restaurants
# Health & Medical, Chiropractors
#
#
# User name: Alex
# ---------------------------------
# The resturant that the user visited:
# Pizza, Restaurants
# Coffee & Tea, Bakeries, Restaurants, Food, Donuts, Breakfast & Brunch
# Arts & Entertainment, Arcades, Amusement Parks, Cinema, Active Life, Local Flavor, Nightlife, Pool Halls
# Vietnamese, Sandwiches, Soup, Cocktail Bars, Restaurants, Bars, Nightlife, Asian Fusion
# American (New), American (Traditional), Restaurants, Gastropubs, Nightlife, Pubs, Bars, British, Irish
# Restaurants, Gluten-Free, Vegetarian, Indian
# Restaurants, Breakfast & Brunch, American (New)
# Steakhouses, Butcher, Wine Bars, American (New), Specialty Food, Meat Shops, Nightlife, Food, Restaurants, Bars, Sandwiches
# American (New), Food, Restaurants, Nightlife, Bars, Cinema, Arts & Entertainment
# Restaurants, Sandwiches, Pubs, American (New), Tapas/Small Plates, Brewpubs, Nightlife, Bars, American (Traditional), Breweries, Food
# Lounges, Nightlife, American (Traditional), Bars, Restaurants
# Beer, Wine & Spirits, Food

# %%
# Thai
print(count/len(Final_TopN_user))
# Out:
# 0.21428571428571427

# %%
# American
print(count/len(Final_TopN_user))
# Out:
# 0.8354430379746836

# %%
# Coffee
print(count/len(Final_TopN_user))
# Out:
# 0.6842105263157895

# %%
# Pasta
print(count/len(Final_TopN_user))
# Out:
# 0.4883720930232558

# %%
# Pizza
print(count/len(Final_TopN_user))
# Out:
# 0.574468085106383

# %%
# Burger
print(count/len(Final_TopN_user))
# Out:
# 0.4533333333333333

# %%
# Thai
print(count/len(Final_TopN_user))
# Out:
# 0.21428571428571427
